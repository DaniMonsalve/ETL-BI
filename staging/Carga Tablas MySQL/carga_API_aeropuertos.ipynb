# %%
pip install pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install mysqlclient

# %%
#LIBRERIAS:

import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
ciudades = ['MAD', 'BCN', 'PEK', 'DMM','DEN','DFW', 'IAD', 'ATL','ORD','LAX','MEX','SJO','LIS','CDG','BER']

# %%
token=''
headers = {"Authorization":"Bearer " + token}

api = 'https://public-cm.onairnet.xyz/api/airports?filters[iata][$eq]='

# %%
datos_API = []
for ciudad in ciudades:
    
    endpoint = api + ciudad +'&locale=en'
    response = requests.get(endpoint, headers=headers) # envío de la petición POST
    res_json = response.json() # Decodificamos el JSON que recibimos de la api para trabajarlo como diccionario
    for i in res_json['data']:
        datos_API.append(i)

# %%
datos_id=[]
for data in datos_API:
    datos_id.append(data["id"])
    
datos_id

# %%
datos=[]
for data in datos_API:
    datos.append(data["attributes"])

# %%
df=pd.DataFrame(datos, columns=['name','iata','country','continent','elevation','latitude','longitude'])
df

# %%
df2=pd.DataFrame(datos_id, columns=['airpot_id'])
df2

# %%
df=df2.join(df)
df

# %%
df.columns=['airpot_id','ap_name','iata','country','continent','elevation','latitude','longitude']
df

# %%
dw = mysql.connector.connect(
    host="35.240.116.63",
    user="IMFds_g2_g1",
    password="g2_g1_689",
    database="imf_g2"   
)

user='IMFds_g2_g1'
print(dw)

cursor=dw.cursor()

# %%
engine = create_engine("mysql+mysqldb://IMFds_g2_g1:g2_g1_689@35.240.116.63/imf_g2")

# %%
df.to_sql('g1_airports', con=engine, if_exists='replace',index=False)
